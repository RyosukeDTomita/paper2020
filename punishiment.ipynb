# %%
 import pyautogui as pgui
 # 画面サイズを取得
width, height = pgui.size()
print(width)
print(height)
#ポインターの位置
x, y = pgui.position()
print(x,y)
# Out:
# 1920
# 1080
# 2650 423

# %%
for i in range(1,100,1):
    pgui.moveTo(1357, 937, duration=4.50)
    pgui.click(1357, 937)
    pgui.moveTo(1464, 952, duration=4.50)
    pgui.click(1464, 952)
    pgui.moveTo(769, 522, duration=4.50)
    pgui.click(769, 522)
    pgui.moveTo(1144, 842, duration=4.50)
    pgui.click(1144, 842)
    pgui.moveTo(1143, 750, duration=4.50)
    pgui.click(1143, 750)
    pgui.moveTo(1146, 674, duration=4.50)
    pgui.click(1146, 674)

# %%
for a in range(1,10000,1):
    pgui.typewrite(['iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii'])
